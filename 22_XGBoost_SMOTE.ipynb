# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('03_Cleaned_File(Data Preprocessing).csv')

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  EstimatedSalary    Balance  \
# 0    15634602  Hargrave          619       0   42        101348.88       0.00
# 1    15647311      Hill          608       0   41        112542.58   83807.86
# 2    15619304      Onio          502       0   42        113931.57  159660.80
# 3    15701354      Boni          699       0   39         93826.63       0.00
# 4    15737888  Mitchell          850       0   43         79084.10  125510.82
#
#    NumOfProducts  HasCrCard  Tenure  IsActiveMember  Exited  \
# 0              1          1       2               1       1
# 1              1          1       1               1       0
# 2              3          0       8               0       1
# 3              2          0       1               0       0
# 4              1          1       2               1       0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# 2                  0                0
# 3                  0                0
# 4                  0                1

# %%
X = df.drop(columns = ['CustomerId', 'Surname', 'Exited'])
y = df['Exited']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
scaler = StandardScaler()
columns = ['CreditScore', 'Age', 'EstimatedSalary', 'Balance']
X_train[columns] = scaler.fit_transform(X_train[columns])
X_test[columns] = scaler.transform(X_test[columns])

# %%
y_train.value_counts()
# Out:
# Exited
# 0    5992
# 1    1505
# Name: count, dtype: int64

# %%
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
y_train.value_counts()
# Out:
# Exited
# 0    5992
# 1    5992
# Name: count, dtype: int64

# %%
xgb = XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    random_state=42
)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

# %%
scoring = {
    'accuracy': 'accuracy',
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1'
}
grid_search = GridSearchCV(
    estimator = xgb,
    param_grid = param_grid,
    scoring = scoring, 
    cv = 5,
    refit = 'recall'
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:19] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:22] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:24] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:29] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:30] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:31] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:57:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# ...
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:47] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:49] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:55] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\amand\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [22:59:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraint...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.7, 0.8, 1.0]},
#              refit='recall',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1',
#                       'precision': 'precision', 'recall': 'recall'})

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'learning_rate': 0.2,
#  'max_depth': 5,
#  'n_estimators': 300,
#  'subsample': 0.7}

# %%
best_dt = grid_search.best_estimator_
y_pred = best_dt.predict(X_test)

# %%
cm = confusion_matrix(y_pred, y_test)
cm
# Out:
# array([[1744,  226],
#        [ 224,  306]], dtype=int64)

# %%
ConfusionMatrixDisplay(confusion_matrix = cm).plot()

# %%
class0_accuracy = cm[0,0] / cm[0].sum()
class1_accuracy = cm[1,1] / cm[1].sum()
print(f"Class 0 Accuracy: {class0_accuracy:.2f}")
print(f"Class 1 Accuracy: {class1_accuracy:.2f}")
# Out:
# Class 0 Accuracy: 0.89
# Class 1 Accuracy: 0.58

# %%
print(f'Accuracy : {accuracy_score(y_test, y_pred):.2f}')
print(f'Precision : {precision_score(y_test, y_pred):.2f}')
print(f'Recall : {recall_score(y_test, y_pred):.2f}')
print(f'F1 Score : {f1_score(y_test, y_pred):.2f}')
# Out:
# Accuracy : 0.82
# Precision : 0.58
# Recall : 0.58
# F1 Score : 0.58

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      1968
#            1       0.58      0.58      0.58       532
#
#     accuracy                           0.82      2500
#    macro avg       0.73      0.73      0.73      2500
# weighted avg       0.82      0.82      0.82      2500
