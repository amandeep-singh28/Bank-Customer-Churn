# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, average_precision_score, roc_curve, precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('03_Cleaned_File(Data Preprocessing).csv')

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore  Gender  Age  EstimatedSalary    Balance  \
# 0    15634602  Hargrave          619       0   42        101348.88       0.00
# 1    15647311      Hill          608       0   41        112542.58   83807.86
# 2    15619304      Onio          502       0   42        113931.57  159660.80
# 3    15701354      Boni          699       0   39         93826.63       0.00
# 4    15737888  Mitchell          850       0   43         79084.10  125510.82
#
#    NumOfProducts  HasCrCard  Tenure  IsActiveMember  Exited  \
# 0              1          1       2               1       1
# 1              1          1       1               1       0
# 2              3          0       8               0       1
# 3              2          0       1               0       0
# 4              1          1       2               1       0
#
#    Geography_Germany  Geography_Spain
# 0                  0                0
# 1                  0                1
# 2                  0                0
# 3                  0                0
# 4                  0                1

# %%
X = df.drop(columns = ['CustomerId', 'Surname', 'Exited'])
y = df['Exited']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3,
                                                    random_state = 42,
                                                    stratify = y)

# %%
X_train.head()
# Out:
#       CreditScore  Gender  Age  EstimatedSalary    Balance  NumOfProducts  \
# 6928          751       1   30        134822.05  165257.20              1
# 1835          561       1   56        133167.11  152759.00              2
# 4196          612       1   35         83256.26       0.00              1
# 2642          736       1   27        192131.77   51522.75              1
# 6299          766       0   45        127332.33   97652.96              1
#
#       HasCrCard  Tenure  IsActiveMember  Geography_Germany  Geography_Spain
# 6928          0       3               0                  0                0
# 1835          0       7               0                  0                0
# 4196          1       1               1                  0                1
# 2642          1       5               1                  0                0
# 6299          0       6               0                  1                0

# %%
num_features = ['CreditScore', 'Age', 'EstimatedSalary', 'Balance']
preprocessor = ColumnTransformer(transformers = [('num', StandardScaler(), num_features)],
                                 remainder = 'passthrough')

# %%
steps = [("preprocess", preprocessor),
         ("smote", SMOTE(random_state = 42)),
         ("random_forest", RandomForestClassifier(random_state = 42))]

# %%
steps
# Out:
# [('preprocess',
#   ColumnTransformer(remainder='passthrough',
#                     transformers=[('num', StandardScaler(),
#                                    ['CreditScore', 'Age', 'EstimatedSalary',
#                                     'Balance'])])),
#  ('smote', SMOTE(random_state=42)),
#  ('random_forest', RandomForestClassifier(random_state=42))]

# %%
pipe = Pipeline(steps)
pipe
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['CreditScore', 'Age',
#                                                    'EstimatedSalary',
#                                                    'Balance'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('random_forest', RandomForestClassifier(random_state=42))])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['CreditScore', 'Age',
#                                                    'EstimatedSalary',
#                                                    'Balance'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('random_forest', RandomForestClassifier(random_state=42))])

# %%
y_pred = pipe.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(3000,))

# %%
param_grid = {
    'random_forest__criterion': ['gini', 'entropy'],
    'random_forest__max_depth': [3, 5, 7, 10, 15, 20, None],
    'random_forest__min_samples_split': [2, 5, 10],
    'random_forest__min_samples_leaf': [1, 2, 4]
}

# %%
scoring = {
    'accuracy' : 'accuracy',
    'precision' : 'precision',
    'recall' : 'recall',
    'f1' : 'f1'
}

grid_search = GridSearchCV(estimator = pipe,
                           param_grid = param_grid,
                           cv = 5,
                           scoring = scoring,
                           refit = 'recall'
)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['CreditScore',
#                                                                           'Age',
#                                                                           'EstimatedSalary',
#                                                                           'Balance'])])),
#                                        ('smote', SMOTE(random_state=42)),
#                                        ('random_forest',
#                                         RandomForestClassifier(random_state=42))]),
#              param_grid={'random_forest__criterion': ['gini', 'entropy'],
#                          'random_forest__max_depth': [3, 5, 7, 10, 15, 20,
#                                                       None],
#                          'random_forest__min_samples_leaf': [1, 2, 4],
#                          'random_forest__min_samples_split': [2, 5, 10]},
#              refit='recall',
#              scoring={'accuracy': 'accuracy', 'f1': 'f1',
#                       'precision': 'precision', 'recall': 'recall'})

# %%
grid_search.best_params_
# Out:
# {'random_forest__criterion': 'gini',
#  'random_forest__max_depth': 3,
#  'random_forest__min_samples_leaf': 1,
#  'random_forest__min_samples_split': 2}

# %%
best_dt = grid_search.best_estimator_
y_pred = best_dt.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1967,  422],
#        [ 170,  441]])

# %%
ConfusionMatrixDisplay(confusion_matrix = cm).plot()

# %%
class0_accuracy = cm[0,0] / cm[0].sum()
class1_accuracy = cm[1,1] / cm[1].sum()
print(f"Class 0 Accuracy: {class0_accuracy:.2f}")
print(f"Class 1 Accuracy: {class1_accuracy:.2f}")
# Out:
# Class 0 Accuracy: 0.82
# Class 1 Accuracy: 0.72

# %%
print(f'Accuracy : {accuracy_score(y_test, y_pred):.2f}')
print(f'Precision : {precision_score(y_test, y_pred):.2f}')
print(f'Recall : {recall_score(y_test, y_pred):.2f}')
print(f'F1 Score : {f1_score(y_test, y_pred):.2f}')
# Out:
# Accuracy : 0.80
# Precision : 0.51
# Recall : 0.72
# F1 Score : 0.60

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      2389
#            1       0.51      0.72      0.60       611
#
#     accuracy                           0.80      3000
#    macro avg       0.72      0.77      0.73      3000
# weighted avg       0.84      0.80      0.81      3000

# %%
y_prob = best_dt.predict_proba(X_test)[:, 1]
y_prob
# Out:
# array([0.27520518, 0.44066034, 0.30094162, ..., 0.25288217, 0.35115909,
#        0.39525818], shape=(3000,))

# %%
roc_auc = roc_auc_score(y_test, y_prob)
pr_auc = average_precision_score(y_test, y_prob)
print(f"ROC-AUC Score:{roc_auc:.2f}")
print(f"PR-AUC Score:{pr_auc:.2f}")
# Out:
# ROC-AUC Score:0.85
# PR-AUC Score:0.63

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

plt.figure(figsize = (6,4))
plt.plot(fpr, tpr, label="ROC Curve")
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

plt.figure(figsize=(6,4))
plt.plot(recall, precision, label="PR Curve")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()
